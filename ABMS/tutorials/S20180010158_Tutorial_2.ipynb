# %%
import arviz as az
import numpy as np
import scipy
import matplotlib.pyplot as plt

from scipy.integrate import odeint

# %%
RANDOM_SEED = 8927
rng = np.random.default_rng(RANDOM_SEED)
plt.style.use("arviz-darkgrid")

# %%
# Given
alpha = 0.4
beta = 0.4
delta = 0.09
gamma = 2.0

# %%
# Time
times = np.linspace(0, 50, 100)
prey_t0 = 100
predator_t0 = 8

# %%
def equations(population_now, t):
    prey, predator = population_now
    dprey_dt = alpha * prey - beta * prey * predator
    dpredator_dt = -gamma * predator + delta * prey * predator
    return dprey_dt, dpredator_dt

# %%
values = odeint(equations, [prey_t0, predator_t0], times, full_output=True)

# %%
prey, predator = values[0].T
f1 = plt.figure()
plt.plot(times, prey, 'r-', label='prey')
plt.plot(times, predator  , 'b-', label='predator')
plt.grid()
plt.legend(loc='best')
plt.xlabel('time')
plt.ylabel('population')
plt.title('Evolution of prey and predator populations');

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w
# Out:
# Last updated: Thu Aug 26 2021
#
# Python implementation: CPython
# Python version       : 3.7.7
# IPython version      : 7.26.0
#
# sys       : 3.7.7 (default, May  6 2020, 04:59:01)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# arviz     : 0.11.2
# matplotlib: 3.4.3
# scipy     : 1.7.1
# numpy     : 1.21.2
#
# Watermark: 2.2.0
